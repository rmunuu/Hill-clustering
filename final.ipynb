# %%
from utils import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import (make_blobs, make_circles, make_moons)
import pickle
from scipy.ndimage import label

# %%
with open('./data/data_pickle/data_0.pkl', 'rb') as file:
    data = pickle.load(file)
    
data = np.array(data)
plt.scatter(data[:, 0], data[:, 1])

# %%
plot_data_hill(data, 0.1, 400)

# %%
level_bin_array, edge = simul_edge(data, (1, 1), 400, 100, 0.1, 3)

# %%
plot_level(level_bin_array, 1)

# %%
edge_array = [[1 for _ in range(103)] for _ in range(103)]
for i, j in edge:
    edge_array[i][j] = 0
edge_array = np.array(edge_array)

plt.imshow(edge_array[::-1], cmap='binary', extent=[0, 1, 0, 1])
# plt.gca().set_aspect('equal', adjustable='box')

# %%
data = np.array(data)
plt.imshow(~edge_array[::-1], cmap='binary', extent=[0, 1, 0, 1])
plt.scatter(data[:, 0], data[:, 1])
plt.show()
