# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
# with open('data_num.pkl', 'rb') as f:
#     data_num = pickle.load(f)

# %%
with open('data_num.pkl', 'wb') as f:
    pickle.dump(0, f)

# %%
with open('./data_pickle/data_0.pkl', 'rb') as f:
    data = pickle.load(f)

plt.scatter(data[:, 0], data[:, 1])
plt.show()
