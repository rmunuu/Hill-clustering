# %%
from utils import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import (make_blobs, make_circles, make_moons)
import pickle
from scipy.ndimage import label

# %%
with open('./data/data_pickle/data_0.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
X1 = make_circles(factor=0.5, noise=0.05, n_samples=500)[0]
X2 = make_moons(n_samples=500, noise=0.05)[0]
X3 = make_blobs(n_samples=500, random_state=42, cluster_std=3)[0]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
if len(X1.shape) == 1:
    X1 = X1.reshape(-1, 1)

scaler = MinMaxScaler(feature_range=(0, 1))
if len(X2.shape) == 1:
    X2 = X2.reshape(-1, 1)

scaler = MinMaxScaler(feature_range=(0, 1))
if len(X3.shape) == 1:
    X3 = X3.reshape(-1, 1)

# %%
data = scaler.fit_transform(X3)

# %%
grid = 400
sub_list = [131, 132, 133]
s_list = [0.01, 0.05, 0.2]
title_list = ['s=0.01', 's=0.05', 's=0.2']

fig = plt.figure(figsize=(15, 5))

for i in range(3):
    s = s_list[i]
    title = title_list[i]
    x = np.linspace(0, 1, grid+1)
    y = np.linspace(0, 1, grid+1)
    x, y = np.meshgrid(x, y)

    z = np.zeros_like(x)
    for point in data:
        z += gaussian(x, y, point[0], point[1], s)

    ax = fig.add_subplot(sub_list[i], projection='3d')
    ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none')
    ax.set_title(title)

plt.show()

# %%
level_bin_array, edge = simul_edge(data, lim=(1, 1), grid=400, ball=100, sigma=0.07, k=2)

edge_array = [[1 for _ in range(103)] for _ in range(103)]
print(edge)
for i, j in edge:
    edge_array[i][j] = 0
edge_array = np.array(edge_array)
data = np.array(data)
plt.imshow(~edge_array[::-1], cmap='binary', extent=[0, 1, 0, 1])
plt.scatter(data[:, 0], data[:, 1])
plt.title("sigma=0.07, k=2")
plt.show()
# Out:
# [[18, 17], [19, 18], [17, 17], [20, 18], [16, 17], [21, 18], [15, 17], [22, 18], [68, 83], [79, 27], [14, 17], [23, 18], [69, 83], [70, 82], [13, 17], [24, 18], [80, 28], [12, 17], [25, 18], [63, 85], [80, 29], [11, 17], [26, 18], [64, 85], [82, 68], [83, 67], [9, 72], [10, 17], [10, 71], [27, 18], [65, 85], [81, 70], [82, 69], [83, 66], [8, 72], [9, 17], [11, 71], [36, 85], [38, 85], [59, 86], [70, 18], [71, 19], [72, 20], [73, 21], [79, 73], [81, 71], [7, 72], [8, 17], [12, 71], [34, 84], [37, 85], [60, 86], [66, 84], [67, 16], [69, 18], [72, 81], [73, 80], [74, 21], [74, 79], [75, 78], [76, 77], [77, 76], [79, 74], [80, 71], [84, 65], [6, 72], [7, 17], [13, 71], [32, 83], [35, 84], [58, 87], [61, 86], [66, 16], [67, 84], [69, 17], [71, 81], [78, 74], [80, 72], [84, 64], [5, 72], [6, 17], [14, 71], [33, 83], [57, 87], [62, 86], [64, 15], [68, 17], [75, 22], [78, 75], [85, 42], [86, 43], [4, 72], [5, 17], [15, 71], [56, 87], [65, 15], [85, 41], [85, 63], [86, 44], [3, 72], [4, 17], [16, 71], [21, 73], [22, 74], [23, 75], [24, 76], [25, 77], [26, 78], [27, 79], [28, 80], [29, 81], [30, 82], [35, 16], [36, 15], [55, 87], [76, 23], [85, 40], [85, 62], [86, 45], [2, 72], [17, 71], [21, 72], [31, 82], [33, 17], [34, 16], [37, 15], [54, 87], [85, 39], [85, 61], [86, 46], [1, 72], [18, 71], [20, 72], [32, 17], [38, 15], [53, 87], [77, 24], [84, 39], [3, 17], [19, 71], [31, 17], [39, 15], [52, 87], [84, 38], [86, 60], [87, 47], [2, 17], [20, 71], [30, 17], [40, 15], [51, 87], [78, 25], [84, 37], [86, 59], [87, 48], [1, 17], [30, 18], [50, 87], [78, 26], [84, 36], [87, 49], [29, 18], [41, 14], [49, 87], [83, 36], [87, 50], [28, 18], [42, 14], [48, 87], [83, 35], [87, 51], [43, 14], [47, 87], [83, 34], [87, 52], [44, 14], [46, 87], [83, 33], [87, 53], [45, 14], [82, 33], [87, 54], [46, 14], [82, 32], [87, 55], [42, 86], [43, 87], [47, 14], [82, 31], [41, 86], [44, 87], [48, 14], [81, 31], [86, 58], [87, 57], [40, 86], [45, 87], [49, 14], [81, 30], [87, 56], [39, 86], [50, 14], [51, 14], [52, 14], [53, 14], [54, 14], [55, 14], [56, 14], [57, 14], [58, 14], [59, 14], [60, 14], [61, 14], [62, 14], [63, 14]]

# %%
plot_level(level_bin_array, 2)

# %%
plot_data_hill(data, 0.07, 400)

# %%
plot_level(level_bin_array, 4)

# %%
level_bin_array, edge = simul_edge(data, (1, 1), 400, 100, 0.05, 2)

edge_array = [[1 for _ in range(103)] for _ in range(103)]
for i, j in edge:
    edge_array[i][j] = 0
edge_array = np.array(edge_array)
data = np.array(data)
plt.imshow(~edge_array[::-1], cmap='binary', extent=[0, 1, 0, 1])
plt.scatter(data[:, 0], data[:, 1])
plt.title("sigma=0.05, k=2")
plt.show()

# %%
level_bin_array, edge = simul_edge(data, (1, 1), 400, 100, 0.09, 3)

edge_array = [[1 for _ in range(103)] for _ in range(103)]
for i, j in edge:
    edge_array[i][j] = 0
edge_array = np.array(edge_array)
data = np.array(data)
plt.imshow(~edge_array[::-1], cmap='binary', extent=[0, 1, 0, 1])
plt.scatter(data[:, 0], data[:, 1])
plt.title("sigma=0.09, k=3")
plt.show()

# %%
plot_level(level_bin_array, size1=1)

# %%
level_bin_array, edge = simul_edge(data, (1, 1), 400, 100, 0.05, 2)

edge_array = [[1 for _ in range(103)] for _ in range(103)]
for i, j in edge:
    edge_array[i][j] = 0
edge_array = np.array(edge_array)
data = np.array(data)
plt.imshow(~edge_array[::-1], cmap='binary', extent=[0, 1, 0, 1])
plt.scatter(data[:, 0], data[:, 1])
plt.title("sigma=0.05, k=2")
plt.show()
